# %% [markdown]
# # FPSO Failure Analysis
#
# * **`Author:`** Lucas Mascarenhas Almeida
# * **`Email:`** lucasmascalmeida@gmail.com
# * **`GitHub:`** (mascalmeida)[https://github.com/mascalmeida]
# * **`Date:`** August 31, 2025

# %% [markdown]
# ### PACKAGES & MODULES

# %% [markdown]
# ### PATHS & VARIABLES

# %%
# code here

# %% [markdown]
# ### FUNCTIONS & CLASSES
# **IMPORTANT** -> Temporary stage the next step should be to **create modules** for each function and remove these cells

# %% [markdown]
# ##### Function 1
#
# * **`Function name:`** XXXXXX
# * **`Description:`** XXXXXX

# %%
# code here

# %% [markdown]
# ##### Function 2
#
# * **`Function name:`** XXXXXX
# * **`Description:`** XXXXXX

# %%
# code here

# %% [markdown]
# ### DATA INGESTION
# **`List of files:`**
# 1. file1.xlsx
# 2. file2.csv
# 3. file3.csv

# %%
# code here

# %% [markdown]
# ### BUSINESS RULES IMPLEMENTATION
#
# **IMPORTANT** -> The code must be **commented** and **explained**

# %% [markdown]
# #### Cell 01
#
# **`List of inputs:`**
# 1. df_a
# 2. df_b
#
# **`List of outputs:`**
# 1. df_ab

# %%
# rules about the cell 01 here

# %% [markdown]
# #### Cell 02
#
# **`List of inputs:`**
# 1. df_c
#
# **`List of outputs:`**
# 1. df_c_filtered

# %%
# rules about the cell 02 here

# %% [markdown]
# ### CHECKING & VALIDATION
#
# Validation steps before loading data. There are **`two obligatory steps:`**
# 1. Incremental checking
# 2. Data type validation
#
# Feel free to implement other steps like the number of rows/columns, null values cells and etc.

# %%
# validation code here

# %% [markdown]
# ### LOAD & SAVE DATA

# %%
# code here
